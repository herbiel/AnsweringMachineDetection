# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
RECORDINGS_PATH = "/Users/habi/Downloads"
PICKLE_FILE_NAME  = "df-40-200-mfccs-kaiser_fast-01-25-19"

# %%
#compute
import glob, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import uuid

os.chdir(RECORDINGS_PATH)

def process(file, label):
    print("processing {}".format(file))
    
    # here kaiser_fast is a technique used for faster extraction
    X, sample_rate = librosa.load(file, res_type='kaiser_fast') 
    duration = librosa.get_duration(X, sample_rate)
    stft = np.abs(librosa.stft(X))
    mfccs_40 = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0) 
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    #mel = np.mean(melspectrogram.T,axis=0)
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),
    sr=sample_rate).T,axis=0)

    row = pd.Series({'file_path':file,'mfccs_40':mfccs_40, 'chroma':chroma, 'mel':mel, 'contrast':contrast, 'tonnetz':tonnetz, 'duration':duration,'label':label},name=7)
    df.loc[len(df)] = row  
    


def download_files(path, label, max=100):
  index = 0
  for file in glob.glob(path):
    if index <=max:
      row = process(file, label)
      df.loc[len(df)] = row
      index = index +1

#save the df for reusabality
# df.to_pickle(PICKLE_FILE_NAME+".pkl")

# %%
df = pd.DataFrame(columns=['file_path', 'mfccs_40', 'chroma', 'mel','contrast','tonnetz', 'duration','label'])
df = df.fillna(0) # with 0s rather than NaNs

# os.chdir(RECORDINGS_PATH)
download_files("normal_voice/*.wav", label="beep")
download_files("voice/*.wav", label="speech")
# Out:
# processing normal_voice/290d0c83-d0f0-8b14-8572-fc312bac886b_81313456346.wav
# processing normal_voice/8b8ee4ed-221b-6222-29f8-7af73a058a35_85391117974.wav
# processing normal_voice/b2788eea-54c6-013b-e44b-5553306d8a92_81335232335.wav
# processing normal_voice/303b97cd-9744-d93e-98f4-260e05cf9e5b_82217438437.wav
# processing normal_voice/d136332c-e996-8811-9669-152bb8aa3e09_82113480090.wav
# processing normal_voice/42bb5f05-4eff-d343-e51d-466ee32a91a7_82115388649.wav
# processing normal_voice/63918ed5-5bc7-7be3-ca9e-29ec0baec1f5_81324244855.wav
# processing normal_voice/6aaf6ea2-5ec8-6279-fa39-e625c4792c39_82317743514.wav
# processing normal_voice/8797ba68-4068-020f-dfd3-c1a4c8387f14_895334103061.wav
# processing normal_voice/d0dea90b-1ac1-b5ac-a1d1-b0979d4a93c3_89522894498.wav
# processing normal_voice/fffcff86-efa8-f567-90ec-7ace2a497b1f_81335232442.wav
# processing normal_voice/e8ff4d21-311a-50ab-8174-a4b309f698e6_81277274412.wav
# processing normal_voice/d20369cf-30f3-6d37-a77f-b7fa0a6f8a22_85719411960.wav
# 42  voice/0d5a1e19-fe47-01ef-9674-a70f9e21f7f4_813...
# 44  voice/31e2602e-c99c-dc6b-9e68-e2ebb95ba25b_895...
# 46  voice/783812c9-53ce-d94f-9e18-b1b1289e8bbb_858...
# 48  voice/04b7be05-021f-8987-3b50-cd17176ef1ef_821...
#
#                                              mfccs_40  \
# 0   [-571.3539, 16.948996, 0.036792982, 3.9366152,...
# 2   [-563.32983, 34.736164, -3.881335, 3.2611938, ...
# 4   [-550.4415, 31.06256, -2.6949258, 5.325177, 7....
# 6   [-585.27545, 23.225786, -1.3455567, 2.8895302,...
# 8   [-538.18506, 37.829617, -7.15697, 3.5153756, 6...
# 10  [-542.05835, 31.414179, -2.902066, 4.9866657, ...
# 12  [-566.7058, 20.136742, -0.58376753, 4.2171974,...
# 14  [-570.2215, 17.724136, -0.07782427, 4.0327783,...
# 16  [-534.15967, 27.858881, -0.43708658, 3.8476334...
# 18  [-546.7873, 18.370195, -2.455056, 1.3241324, 4...
# 20  [-546.4911, 29.90451, -1.8657427, 5.354059, 6....
# 22  [-582.17, 22.445503, -3.8231952, 0.68891764, 5...
# 24  [-556.23, 39.866543, -4.1801724, 5.3843555, 8....
# 26  [-563.9232, 19.947777, -0.2232292, 4.3809395, ...
# 28  [-507.48468, 51.1896, -6.6262403, 5.102897, 9....
# 30  [-294.23056, 173.8012, -18.917114, 10.309621, ...
# 32  [-337.04706, 127.346855, -38.66155, 11.93957, ...
# 34  [-301.30704, 139.00377, -36.06642, 3.1129656, ...
# 36  [-313.83524, 155.59308, -19.987486, 5.245352, ...
# 38  [-320.07556, 156.14436, -16.233452, 8.241486, ...
# 40  [-380.35458, 136.56969, -37.712055, 3.3214962,...
# 42  [-287.9139, 156.33928, -38.815308, 7.8761024, ...
# 44  [-361.20145, 144.22142, -10.244465, 16.758013,...
# 46  [-325.35342, 134.9701, -40.548847, 12.213521, ...
# 48  [-289.03943, 177.84055, -19.528896, 8.433224, ...
#
#                                                chroma  \
# 0   [0.72958076, 0.79309595, 0.84281105, 0.8778919...
# 2   [0.62028545, 0.66711754, 0.6961068, 0.72624785...
# 4   [0.6395512, 0.69527966, 0.7418388, 0.7739457, ...
# 6   [0.69682956, 0.75037056, 0.7902981, 0.82167166...
# 8   [0.66811734, 0.7184075, 0.76485026, 0.7948932,...
# 10  [0.64156616, 0.700777, 0.74567425, 0.776261, 0...
# 12  [0.71005964, 0.77173513, 0.8210175, 0.85425735...
# 14  [0.7250358, 0.7885404, 0.83768237, 0.8715407, ...
# 16  [0.734862, 0.79395396, 0.82848823, 0.85650086,...
# 18  [0.72039396, 0.7847391, 0.8356158, 0.86803436,...
# 20  [0.6478617, 0.70444334, 0.74986863, 0.7810905,...
# 22  [0.71193606, 0.7626357, 0.801884, 0.8295044, 0...
# 24  [0.16769676, 0.22216131, 0.5478355, 0.23450075...
